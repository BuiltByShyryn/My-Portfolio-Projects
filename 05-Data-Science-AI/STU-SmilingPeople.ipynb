# %%
from ultralytics import YOLO

# 1. Load the "Nano" model 
model = YOLO('yolov8n.pt') 

# 2. Start Training!
# Change 'C:/path/to/your/data.yaml' to the ACTUAL path on your computer.
results = model.train(
    data=r"C:\Users\nikak\Downloads\Smile.v2-smiling_people.yolov8\data.yaml", 
    epochs=10,      # Start with 10 to make sure it works
    imgsz=640,     # Standard size for YOLO
    plots=True     # This will save charts!
)

print("✨ TRAINING FINISHED! Check the 'runs/detect/train' folder for results!")
# Out:
# ...
# Ultralytics 8.4.6  Python-3.14.0 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# ...
